# %%
# Import Libraries

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) #Adjusts the configuration of the plots we will create

#Read in the data

df = pd.read_csv(r'C:\Users\rahulshankariyer\Documents\Vaccinations vs Covid Cases and Deaths by date.csv')

# %%
#Let's look at the date wise data

df.head()
# Out:
#        date  total_cases  total_deaths  total_vaccinations
# 0  1/1/2020            0             0                 NaN
# 1  1/2/2020            0             0                 NaN
# 2  1/3/2020            0             0                 NaN
# 3  1/4/2020            0             0                 NaN
# 4  1/5/2020            0             0                 NaN

# %%
#Replacing null values with 0

df.replace(to_replace = np.nan,value = 0)
# Out:
#       date  total_cases  total_deaths  total_vaccinations
# 0        0            0             0                 0.0
# 1       33            0             0                 0.0
# 2       66            0             0                 0.0
# 3       75            0             0                 0.0
# 4       78            0             0                 0.0
# ...    ...          ...           ...                 ...
# 1051   212       472716          2593            797085.0
# 1052   215       627045          2307            556706.0
# 1053   218       246330           423            142226.0
# 1054   224       221701           509            797743.0
# 1055   227       355944          1037                 0.0
#
# [1056 rows x 4 columns]

# %%
#Vaccination vs Cases date wise

sns.regplot(x = 'total_vaccinations',y = 'total_cases',data = df,scatter_kws = {"color" : "red"},line_kws = {"color" : "blue"})
# Out:
# <AxesSubplot:xlabel='total_vaccinations', ylabel='total_cases'>

# %%
#Vaccination vs Deaths date wise

sns.regplot(x = 'total_vaccinations',y = 'total_deaths',data = df,scatter_kws = {"color" : "red"},line_kws = {"color" : "blue"})
# Out:
# <AxesSubplot:xlabel='total_vaccinations', ylabel='total_deaths'>

# %%
#Correlation

correlation_matrix = df.corr(method = 'pearson')
sns.heatmap(correlation_matrix,annot = True)
plt.title('Correlation Matrix for Covid Vaccinations against Cases & Deaths according to date')
plt.show()

# %%
for col_name in df.columns:
    if(df[col_name].dtype == 'object'):
        df[col_name] = df[col_name].astype('category')
        df[col_name] = df[col_name].cat.codes

df
# Out:
#       date  total_cases  total_deaths  total_vaccinations
# 0        0            0             0                 NaN
# 1       33            0             0                 NaN
# 2       66            0             0                 NaN
# 3       75            0             0                 NaN
# 4       78            0             0                 NaN
# ...    ...          ...           ...                 ...
# 1051   212       472716          2593            797085.0
# 1052   215       627045          2307            556706.0
# 1053   218       246330           423            142226.0
# 1054   224       221701           509            797743.0
# 1055   227       355944          1037                 NaN
#
# [1056 rows x 4 columns]

# %%
#Vaccination vs Date

sns.regplot(x = 'date',y = 'total_vaccinations',data = df,scatter_kws = {"color" : "red"},line_kws = {"color" : "blue"})
# Out:
# <AxesSubplot:xlabel='date', ylabel='total_vaccinations'>

# %%
#Vaccination vs Cases

sns.regplot(x = 'date',y = 'total_cases',data = df,scatter_kws = {"color" : "red"},line_kws = {"color" : "blue"})
# Out:
# <AxesSubplot:xlabel='date', ylabel='total_cases'>

# %%
#Vaccination vs Deaths

sns.regplot(x = 'date',y = 'total_deaths',data = df,scatter_kws = {"color" : "red"},line_kws = {"color" : "blue"})
# Out:
# <AxesSubplot:xlabel='date', ylabel='total_deaths'>

# %%
#Insights
#1. The number of people getting vaccinated steadily increased each day
#2. The number of people getting infected by Covid-19 steadily decreased each day
#3. The number of people getting dying from Covid-19 steadily decreased each day

# %%
#Conclusion
#The steady increase in vaccinations combined with a similar decrease in Covid-19 infections & deaths suggests that the vaccines are indeed proving effective in countering the Covid-19 Pandemic.
